# %%
def isSub():
  s = "abc"
  t = "ahbbgdc"
  count = []

  for i in range(len(s)):
    for j in range(len(t)):
      if s[i] == t[j]:
        print(s[i] , t[j], ">>>>>")
        count.append(t[j])

  nw = set(count)
  if len(nw) == len(s):
    return True

  return False

isSub()
# Out:
# a a >>>>>
# b b >>>>>
# b b >>>>>
# c c >>>>>
# True

# %%
import os
import shutil
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')

# Define paths
dsa_folder_path = '/content/drive/MyDrive/Colab Notebooks/DSA'  # Google Drive folder with your DSA files
repo_path = '/content/LeetCode-150-interview-Questions'  # Repo path

# Check if the repo already exists, to avoid re-running the cloning or setup steps
if not os.path.exists(repo_path):
    print(f"Cloning the repository to {repo_path}")
    # !git clone https://github.com/shakthi01912/LeetCode-150-interview-Questions.git /content/LeetCode-150-interview-Questions
else:
    print(f"Repository already exists at {repo_path}")

# Copy the DSA files to the repo folder
for file_name in os.listdir(dsa_folder_path):
    source = os.path.join(dsa_folder_path, file_name)
    destination = os.path.join(repo_path, file_name)
    if os.path.isfile(source):
        shutil.copy(source, destination)
        print(f"Copied {file_name} to GitHub repo.")

# Change to the repo directory
os.chdir(repo_path)

# Git commands to commit and push the changes

# First, set up your Git user name and email (if not already configured)
# !git config --global user.email "mshakthi019@gmail.com"  # Replace with your GitHub email
# !git config --global user.name "shakthi01912"  # Replace with your GitHub name

# Stage all the files for commit
# !git add .

# Commit changes if there are any
# !git commit -m "Add files from DSA folder" || echo "No changes to commit."

# Push changes to GitHub (only if there's a commit)
# !git push -u origin main  # Make sure the branch is 'main', otherwise use 'master'

print("Files pushed to GitHub repo.")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Repository already exists at /content/LeetCode-150-interview-Questions
# Copied BubbleSort.ipynb to GitHub repo.
# Copied 88. Merge Sorted Array.ipynb to GitHub repo.
# Copied mergeSorted.ipynb to GitHub repo.
# Copied Find the closest pair from two sorted arrays.ipynb to GitHub repo.
# Copied 392. Is Subsequence.ipynb to GitHub repo.
# Copied 125. Valid Palindrome.ipynb to GitHub repo.
# Copied 167. Two Sum II - Input Array Is Sorted.ipynb to GitHub repo.
# Copied 11. Container With Most Water.ipynb to GitHub repo.
# Copied 15. 3Sum.ipynb to GitHub repo.
# Copied GFG- Sum – Triplet Sum in Arrayd0.ipynb to GitHub repo.
# Copied 27. Remove Element.ipynb to GitHub repo.
# Copied 26. Remove Duplicates from Sorted Array.ipynb to GitHub repo.
# Copied git_setup.ipynb to GitHub repo.
# [main e0721c4] Add files from DSA folder
# ...

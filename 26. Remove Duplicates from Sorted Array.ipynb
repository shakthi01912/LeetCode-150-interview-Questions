# %%
nums = [0,0,1,2]
def removeDuplicates():
  n = len(nums)
  k = 1

  if n == 0:
    return 0

  for i in range(1 , n):
    if nums[i] != nums[k-1]:
      nums[k] == nums[i]
      k += 1


  return k





removeDuplicates()
# print(nums[::k])
# Out:
# 3

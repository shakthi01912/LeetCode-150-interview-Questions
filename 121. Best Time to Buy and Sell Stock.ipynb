# %%
prices = [7,1,5,3,6,4]
def maxProfit():
  n = len(prices)
  mp = float('inf')
  xp = 0


  for i in prices:

    if i < mp:
        mp = i


    current_profit = i - mp
    if current_profit > xp:
        xp = current_profit

  return xp


maxProfit()
# Out:
# 5

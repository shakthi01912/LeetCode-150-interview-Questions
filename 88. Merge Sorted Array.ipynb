# %%
# nums1 = [1,2,3,0,0,0], m = 3, nums2 = [2,5,6], n = 3

# def merge(self, nums1, m, nums2, n):
#   while 0 < n:
#     for a in range(m):
#       if b in range(n)
#         if nums1[a] > nums2[a]:

# %%
nums1 = [1,2,3,0,0,0]
m = 3
nums2 = [2,5,6]
n = 3
n = len(nums1)

def merge(self, nums1, m, nums2, n):
  for  p1 in range(n ,  -1):
    for p2 in range(p1 , -1):
      if p1 > p2:
        for p in range(n , -1):
          temp = nums2[p2]
          nums1[p] = nums2[p2]
          nums2[p2] = temp


print(nums1)
# Out:
# [1, 2, 3, 0, 0, 0]

# %%
def merge(nums1, m, nums2, n):
    # Initialize pointers
    p1 = m - 1  # Last element in nums1's meaningful part
    p2 = n - 1  # Last element in nums2
    p = m + n - 1  # Last position in nums1

    # Merge from the end of nums1 and nums2
    while p1 >= 0 and p2 >= 0:
        if nums1[p1] > nums2[p2]:
            nums1[p] = nums1[p1]
            p1 -= 1
        else:
            nums1[p] = nums2[p2]
            p2 -= 1
        p -= 1

    # If nums2 still has elements left, copy them
    while p2 >= 0:
        nums1[p] = nums2[p2]
        p2 -= 1
        p -= 1

# Example usage
nums1 = [1, 2, 3, 0, 0, 0]
m = 3
nums2 = [2, 5, 6]
n = 3

merge(nums1, m, nums2, n)
print(nums1)  # Output: [1, 2, 2, 3, 5, 6]
# Out:
# [1, 2, 2, 3, 5, 6]
